# %%
# !apt-get update && apt-get install -y graphviz
# !pip install pytz
# !pip install networkx
# !pip install pyyaml
# !pip install graphviz
# !pip install lingam

# %%
import time

start = time.time()

# %%
import os
import logging
from pytz import timezone
from datetime import datetime
import numpy as np

from data_loader import SyntheticDataset
from models import NoTears
from trainers import ALTrainer
from helpers.config_utils import save_yaml_config, get_train_args
from helpers.log_helper import LogHelper
from helpers.tf_utils import set_seed
from helpers.dir_utils import create_dir
from helpers.analyze_utils import count_accuracy, plot_estimated_graph

# For logging of tensorflow messages
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import pandas as pd

# exp_name = 'SKAB'
# exp_name = 'skab_a'
exp_name = 'skab_tempture'
exp_name = 'skab_vibration'
dataset_path = '../../experiment/datasets/{}.csv'.format(exp_name)
# true_path = '../../experiment/datasets/{}_W_true.csv'.format(exp_name)

headers = pd.read_csv(dataset_path, nrows=0).columns.tolist()

headers = [c for c in headers if c != 'datetime']

df = pd.read_csv(dataset_path, usecols=headers)

df = pd.read_csv(dataset_path, usecols=headers)
# df = df[:300]
X = df.to_numpy()

# headers = []
# for i in range(X.shape[1]):
#     headers.append('x{}'.format(i))

df
# Out:
#      Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  Temperature  \
# 0             0.247702           0.288223  3.081540  0.054711      85.7970
# 1             0.244194           0.288359  2.650220  0.382638      85.8968
# 2             0.249325           0.285144  2.854270  0.054711      85.9118
# 3             0.248386           0.289918  2.884110 -0.273216      85.8238
# 4             0.246643           0.288838  3.015220 -0.273216      85.8264
# ..                 ...                ...       ...       ...          ...
# 900           0.105811           0.193051  1.291030  0.054711      86.1452
# 901           0.060570           0.077031  0.824930  0.382638      86.2657
# 902           0.024764           0.037350  0.293163  0.382638      86.5109
# 903           0.017131           0.016978  0.220920  0.054711      86.2620
# 904           0.015752           0.015505  0.149842  0.382638      86.4799
#
#      Thermocouple  Voltage  Volume Flow RateRMS  anomaly  changepoint
# 0         28.7711  233.733            126.00000      0.0          0.0
# 1         28.7714  229.492            126.00000      0.0          0.0
# 2         28.7602  240.890            125.30800      0.0          0.0
# 3         28.7734  237.715            125.69300      0.0          0.0
# 4         28.7734  234.329            126.00000      0.0          0.0
# ..            ...      ...                  ...      ...          ...
# 900       33.2491  208.855            122.47500      0.0          0.0
# 901       33.2489  227.430             98.54010      0.0          0.0
# 902       33.2445  228.719             69.18940      0.0          0.0
# 903       33.2386  245.183             17.65750      0.0          0.0
# 904       33.2464  231.541              2.76765      0.0          0.0
#
# [905 rows x 10 columns]

# %%
# w_true = pd.read_csv(true_path, header=None)
# w_true

# %%
# Get arguments parsed
args = get_train_args()

args.n = X.shape[0]
args.d = X.shape[1]

# %%
# Setup for logging
output_dir = 'output/{}/{}'.format(exp_name, datetime.now(timezone('Asia/Taipei')).strftime('%Y-%m-%d_%H-%M-%S-%f')[:-3])
create_dir(output_dir)
LogHelper.setup(log_path='{}/training.log'.format(output_dir), level_str='INFO')
_logger = logging.getLogger(__name__)

# Save the configuration for logging purpose
save_yaml_config(args, path='{}/config.yaml'.format(output_dir))

# Reproducibility
set_seed(args.seed)

# Get dataset
dataset = SyntheticDataset(args.n, args.d, args.graph_type, args.degree, args.sem_type,
                           args.noise_scale, args.dataset_type)
_logger.info('Finished generating dataset')
# Out:
# 2022-04-18 04:18:41,958 INFO - helpers.log_helper - Finished configuring logger.
# 2022-04-18 04:18:41,961 INFO - __main__ - Finished generating dataset

# %%
dataset.X = X
X
# Out:
# array([[2.47702e-01, 2.88223e-01, 3.08154e+00, ..., 1.26000e+02,
#         0.00000e+00, 0.00000e+00],
#        [2.44194e-01, 2.88359e-01, 2.65022e+00, ..., 1.26000e+02,
#         0.00000e+00, 0.00000e+00],
#        [2.49325e-01, 2.85144e-01, 2.85427e+00, ..., 1.25308e+02,
#         0.00000e+00, 0.00000e+00],
#        ...,
#        [2.47643e-02, 3.73504e-02, 2.93163e-01, ..., 6.91894e+01,
#         0.00000e+00, 0.00000e+00],
#        [1.71308e-02, 1.69777e-02, 2.20920e-01, ..., 1.76575e+01,
#         0.00000e+00, 0.00000e+00],
#        [1.57521e-02, 1.55046e-02, 1.49842e-01, ..., 2.76765e+00,
#         0.00000e+00, 0.00000e+00]])

# %%
# true answer
# dataset.W = w_true.to_numpy()
# w_true

# %%
model = NoTears(args.n, args.d, args.seed, args.l1_lambda, args.use_float64)
model.print_summary(print_func=model.logger.info)

trainer = ALTrainer(args.init_rho, args.rho_max, args.h_factor, args.rho_multiply,
                    args.init_iter, args.learning_rate, args.h_tol)
W_est = trainer.train(model, dataset.X, dataset.W, args.graph_thres,
                      args.max_iter, args.iter_step, output_dir)
_logger.info('Finished training model')
# Out:
# 2022-04-18 04:18:42,743 INFO - models.notears - Model summary:
# 2022-04-18 04:18:42,744 INFO - models.notears - ---------
# 2022-04-18 04:18:42,744 INFO - models.notears - Variables: name (type shape) [size]
# 2022-04-18 04:18:42,745 INFO - models.notears - ---------
# 2022-04-18 04:18:42,745 INFO - models.notears - Variable:0 (float32 10x10) [100, bytes: 400]
# 2022-04-18 04:18:42,745 INFO - models.notears - Total size of variables: 100
# 2022-04-18 04:18:42,746 INFO - models.notears - Total bytes of variables: 400
# 2022-04-18 04:18:42,788 INFO - trainers.al_trainer - Started training for 20 iterations
# 2022-04-18 04:18:42,789 INFO - trainers.al_trainer - rho 1.000E+00, alpha 0.000E+00
# 2022-04-18 04:18:46,290 INFO - trainers.al_trainer - [Iter 1] loss 2.191E+02, mse 3.966E+05, acyclic 1.655E-01, shd 30, tpr 0.095, fdr 0.900, pred_size 20
# 2022-04-18 04:18:46,291 INFO - trainers.al_trainer - rho 1.000E+00, alpha 1.655E-01
# 2022-04-18 04:18:48,947 INFO - trainers.al_trainer - rho 1.000E+01, alpha 1.655E-01
# 2022-04-18 04:18:51,588 INFO - trainers.al_trainer - rho 1.000E+02, alpha 1.655E-01
# 2022-04-18 04:18:54,361 INFO - trainers.al_trainer - rho 1.000E+03, alpha 1.655E-01
# 2022-04-18 04:18:57,202 INFO - trainers.al_trainer - rho 1.000E+04, alpha 1.655E-01
# 2022-04-18 04:19:00,422 INFO - trainers.al_trainer - [Iter 2] loss 1.003E+02, mse 1.674E+05, acyclic 3.957E-02, shd 32, tpr 0.333, fdr 0.800, pred_size 35
# 2022-04-18 04:19:00,423 INFO - trainers.al_trainer - rho 1.000E+04, alpha 3.959E+02
# 2022-04-18 04:19:04,027 INFO - trainers.al_trainer - rho 1.000E+05, alpha 3.959E+02
# 2022-04-18 04:19:07,992 INFO - trainers.al_trainer - [Iter 3] loss 9.259E+01, mse 1.577E+05, acyclic 7.194E-03, shd 30, tpr 0.381, fdr 0.771, pred_size 35
# 2022-04-18 04:19:07,993 INFO - trainers.al_trainer - rho 1.000E+05, alpha 1.115E+03
# 2022-04-18 04:19:12,004 INFO - trainers.al_trainer - rho 1.000E+06, alpha 1.115E+03
# 2022-04-18 04:19:16,017 INFO - trainers.al_trainer - [Iter 4] loss 8.191E+01, mse 1.441E+05, acyclic 1.302E-03, shd 31, tpr 0.286, fdr 0.812, pred_size 32
# 2022-04-18 04:19:16,018 INFO - trainers.al_trainer - rho 1.000E+06, alpha 2.417E+03
# 2022-04-18 04:19:20,304 INFO - trainers.al_trainer - rho 1.000E+07, alpha 2.417E+03
# 2022-04-18 04:19:24,600 INFO - trainers.al_trainer - [Iter 5] loss 7.708E+01, mse 1.386E+05, acyclic 1.554E-04, shd 30, tpr 0.286, fdr 0.806, pred_size 31
# 2022-04-18 04:19:24,601 INFO - trainers.al_trainer - rho 1.000E+07, alpha 3.971E+03
# 2022-04-18 04:19:28,913 INFO - trainers.al_trainer - rho 1.000E+08, alpha 3.971E+03
# 2022-04-18 04:19:33,209 INFO - trainers.al_trainer - rho 1.000E+09, alpha 3.971E+03
# 2022-04-18 04:19:37,530 INFO - trainers.al_trainer - [Iter 6] loss 7.638E+01, mse 1.380E+05, acyclic 1.240E-05, shd 31, tpr 0.286, fdr 0.812, pred_size 32
# 2022-04-18 04:19:37,530 INFO - trainers.al_trainer - rho 1.000E+09, alpha 1.637E+04
# 2022-04-18 04:19:41,839 INFO - trainers.al_trainer - rho 1.000E+10, alpha 1.637E+04
# 2022-04-18 04:19:46,144 INFO - trainers.al_trainer - [Iter 7] loss 7.594E+01, mse 1.374E+05, acyclic 9.537E-07, shd 31, tpr 0.286, fdr 0.818, pred_size 33
# 2022-04-18 04:19:46,145 INFO - trainers.al_trainer - rho 1.000E+10, alpha 2.591E+04
# 2022-04-18 04:19:50,479 INFO - trainers.al_trainer - rho 1.000E+11, alpha 2.591E+04
# 2022-04-18 04:19:54,784 INFO - trainers.al_trainer - rho 1.000E+12, alpha 2.591E+04
# 2022-04-18 04:19:59,098 INFO - trainers.al_trainer - rho 1.000E+13, alpha 2.591E+04
# 2022-04-18 04:20:03,397 INFO - trainers.al_trainer - [Iter 8] loss 8.207E+01, mse 1.485E+05, acyclic 0.000E+00, shd 31, tpr 0.286, fdr 0.812, pred_size 32
# 2022-04-18 04:20:03,398 INFO - trainers.al_trainer - Early stopping at 8-th iteration
# 2022-04-18 04:20:03,439 INFO - trainers.al_trainer - Model saved to output/skab_tempture/2022-04-18_17-18-41-958/model/
# 2022-04-18 04:20:03,441 INFO - __main__ - Finished training model

# %%
# Save raw estimated graph, ground truth and observational data after training
# np.save('{}/true_graph.npy'.format(output_dir), dataset.W)
np.save('{}/X.npy'.format(output_dir), dataset.X)
np.save('{}/final_raw_estimated_graph.npy'.format(output_dir), W_est)

# %%
np.savetxt("{}/W_est.csv".format(output_dir), W_est, delimiter=",")
W_est
# Out:
# array([[ 0.00000000e+00,  7.96132863e-01,  4.16952085e+00,
#         -1.09196384e-03,  8.06191254e+00,  1.13078833e+01,
#         -1.01174998e+00,  1.08591938e+01, -1.06752567e-01,
#         -3.16342083e-03],
#        [ 2.69916249e-08,  0.00000000e+00,  4.18462038e+00,
#          9.76512209e-04,  7.61959219e+00,  1.14453344e+01,
#         -1.54999506e+00,  1.03778458e+01,  1.21402395e+00,
#          2.82771682e-04],
#        [ 6.08338224e-09,  3.05279380e-09,  0.00000000e+00,
#         -1.05228799e-03,  1.90636468e+00,  8.44674587e+00,
#          8.69824696e+00,  2.68930507e+00,  3.72007582e-03,
#         -2.61211710e-04],
#        [ 1.15307812e-02, -3.18176672e-03, -1.49518233e-02,
#          0.00000000e+00,  1.22648942e+00,  2.40401936e+00,
#         -6.97230339e-01, -9.78268325e-01,  2.47891457e-03,
#          2.37433344e-08],
#        [ 2.23865393e-09,  9.58144342e-10,  1.39044500e-08,
#          1.16381024e-07,  0.00000000e+00,  5.36977223e-06,
#          2.28874588e+00,  1.35751569e+00, -1.70997383e-10,
#          1.07609823e-08],
#        [ 1.88279325e-09,  8.65720440e-10,  1.60485563e-08,
#          1.43411057e-07,  2.55973268e+00,  0.00000000e+00,
#          7.79843271e-01, -2.47315630e-01,  5.84782089e-09,
#          5.13846352e-08],
#        [ 3.18093663e-09,  1.34449218e-09,  1.80856858e-08,
#          1.59725744e-07,  3.04063560e-05,  4.96515167e-06,
#          0.00000000e+00,  9.97512229e-03, -2.06811387e-10,
#          5.28079225e-09],
#        [ 5.44180345e-09,  2.30422459e-09,  3.13327781e-08,
#          2.47914301e-07,  4.87539146e-05,  8.10810980e-06,
#         -9.73750129e-02,  0.00000000e+00,  6.08606054e-10,
#          1.84849025e-08],
#        [ 4.10315479e-08,  5.38481926e-09, -7.98409432e-03,
#          1.89906964e-03, -9.54246140e+00,  5.63774490e+00,
#         -2.46621966e+00,  4.50783587e+00,  0.00000000e+00,
#          2.72013494e-07],
#        [-8.78014893e-04, -3.52509320e-03, -3.35389143e-03,
#          1.20186247e-01,  2.57826567e+00, -7.57600367e-01,
#         -4.98757505e+00,  4.39225703e-01,  4.89389822e-02,
#          0.00000000e+00]], dtype=float32)

# %%
# Plot raw estimated graph
plot_estimated_graph(W_est, dataset.W, save_name='{}/raw_estimated_graph.png'.format(output_dir))

results = count_accuracy(dataset.W, W_est)
_logger.info('Results: {}'.format(results))

# _logger.info('Thresholding.')
graph_thres = 0.3
# # Plot thresholded estimated graph

copy_W_est = np.copy(W_est)
copy_W_est[np.abs(copy_W_est) < args.graph_thres] = 0   # Thresholding
plot_estimated_graph(copy_W_est, dataset.W,
                     save_name='{}/thresholded_estimated_graph.png'.format(output_dir))
results_thresholded = count_accuracy(dataset.W, copy_W_est)
_logger.info('Results after thresholding by {}: {}'.format(args.graph_thres, results_thresholded))
# Out:
# 2022-04-18 04:20:03,764 INFO - __main__ - Results: {'fdr': 0.7666666666666667, 'tpr': 1.0, 'fpr': 2.875, 'shd': 45, 'pred_size': 90}
# 2022-04-18 04:20:04,066 INFO - __main__ - Results after thresholding by 0.3: {'fdr': 0.8125, 'tpr': 0.2857142857142857, 'fpr': 1.0833333333333333, 'shd': 31, 'pred_size': 32}

# %%
end = time.time()

_logger.info('The time used to execute this is given below')
_logger.info(end - start)
# Out:
# 2022-04-18 04:20:04,070 INFO - __main__ - The time used to execute this is given below
# 2022-04-18 04:20:04,070 INFO - __main__ - 83.71831512451172

# %%
# c = np.sum(copy_W_est, axis=1)
# c.shape

# %%
# copy_W_est

# %%
#result_matrix = pd.read_csv("W_true.csv", header=None)

# %%
from lingam.utils import make_dot
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['Arial Unicode MS'] #用來正常顯示中文標簽
plt.rcParams['axes.unicode_minus']=False #用來正常顯示負號

dot = make_dot(W_est, labels=headers, lower_limit=graph_thres)

# Save png
dot.format = 'png'
dag_path = dot.render('{}/dag'.format(output_dir))

#dot.render('{}/dag'.format(output_dir))

from IPython.display import Image
Image(filename=dag_path)

# %%
dot = make_dot(w_true, labels=headers)

# Save png
dot.format = 'png'
dag_path = dot.render('{}/true-dag'.format(output_dir))

#dot.render('{}/dag'.format(output_dir))

from IPython.display import Image
Image(filename=dag_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-217dabd81a02> in <module>
# ----> 1 dot = make_dot(w_true, labels=headers)
#       2
#       3 # Save png
#       4 dot.format = 'png'
#       5 dag_path = dot.render('{}/true-dag'.format(output_dir))
#
# NameError: name 'w_true' is not defined
