# %%
import pandas as pd
col_names = ['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19']
df = pd.read_csv('./datasets/n_2000_d_20_e_12_ER/X.csv', header=None, names=col_names)

df
# Out:
#             x0        x1        x2        x3        x4        x5        x6  \
# 0     0.649914  0.110498  0.576432 -1.608471 -0.404442  0.423912  1.118853
# 1     0.160245  0.459786  1.332600 -0.950679 -1.205879 -0.049729  0.438918
# 2    -1.009153  3.344333  0.648607  0.929815  0.195190  0.830069  2.195853
# 3     0.512024  0.754808 -3.224662 -0.376409 -2.829519  0.049672 -0.147237
# 4     0.251512  1.271053  1.364311  0.553115  1.717525 -0.120377 -0.331257
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  0.092790 -0.922265 -0.354043 -0.204768  1.002251  1.925473  1.097267
# 1996  2.179368  0.045639  1.267324 -3.411381  0.827561  0.226023 -1.809985
# 1997  0.812296 -2.104116  0.658408  1.702298 -0.880248 -0.696517 -0.975519
# 1998 -0.062617 -0.510263 -1.071961 -0.854888  0.374902  0.641523 -1.338602
# 1999 -0.670545  1.010352 -0.915364 -0.822362 -2.283317 -0.712958  0.101947
#
# ...
